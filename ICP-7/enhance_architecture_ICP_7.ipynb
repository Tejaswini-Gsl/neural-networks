# %% [markdown]
# <a href="https://colab.research.google.com/github/Tejaswini-Gsl/neural-networks/blob/main/enhance_architecture_ICP_8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.optimizers import RMSprop, Adam
from sklearn.metrics import ConfusionMatrixDisplay
from sklearn.metrics import accuracy_score
from sklearn.metrics import classification_report, confusion_matrix
import warnings
warnings.filterwarnings("ignore")

# %%
(x_train, y_train), (x_test, y_test)  = keras.datasets.cifar10.load_data()

# %%
classes = ["airplane","automobile","bird","cat","deer","dog","frog","horse","ship","truck"]

# %%
y_train = y_train.reshape(-1,)

# %%
# Reshape converting 2D to 1D
y_test = y_test.reshape(-1,)
y_train = y_train.reshape(-1,)

# %%
# This code normalazation
x_train = x_train / 255.0
x_test = x_test / 255.0

# %%
x_train.shape
# Out:
# (50000, 32, 32, 3)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Conv2D
from tensorflow.keras.layers import Dropout
from tensorflow.keras.layers import Flatten
from tensorflow.keras.optimizers import SGD, Adam
from tensorflow.keras.regularizers import l2
from tensorflow.keras.layers import Conv2D, MaxPooling2D, BatchNormalization
# from keras.layers.convolutional import Convolution2D
# from keras.layers.convolutional import MaxPooling2D

# %%
AlexNet = Sequential()

# Normalize input
AlexNet.add(BatchNormalization(input_shape=(32, 32, 3)))

# Convolutional layers
AlexNet.add(Conv2D(filters=32, kernel_size=(3, 3), strides=(1, 1), padding='same', activation='relu', kernel_regularizer=l2(0.001)))
AlexNet.add(BatchNormalization())
AlexNet.add(MaxPooling2D(pool_size=(2, 2), strides=(2, 2)))

AlexNet.add(Conv2D(64, (3, 3), padding='same', activation='relu', kernel_regularizer=l2(0.001)))
AlexNet.add(BatchNormalization())
AlexNet.add(MaxPooling2D(pool_size=(2, 2), strides=(2, 2)))

AlexNet.add(Conv2D(128, (3, 3), padding='same', activation='relu', kernel_regularizer=l2(0.001)))
AlexNet.add(BatchNormalization())
AlexNet.add(Conv2D(128, (3, 3), padding='same', activation='relu', kernel_regularizer=l2(0.001)))
AlexNet.add(BatchNormalization())
AlexNet.add(MaxPooling2D(pool_size=(2, 2), strides=(2, 2)))

# Fully connected layers
AlexNet.add(Flatten())
AlexNet.add(Dense(256, activation='relu', kernel_regularizer=l2(0.001)))
AlexNet.add(Dropout(0.3))
AlexNet.add(Dense(256, activation='relu', kernel_regularizer=l2(0.001)))
AlexNet.add(Dropout(0.3))
AlexNet.add(Dense(10, activation='softmax'))

# Compile model
AlexNet.compile(optimizer=Adam(lr=0.001), loss='sparse_categorical_crossentropy', metrics=['accuracy'])

AlexNet.summary()
# Out:
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# Model: "sequential_11"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  batch_normalization_41 (Ba  (None, 32, 32, 3)         12
#  tchNormalization)
#
#  conv2d_37 (Conv2D)          (None, 32, 32, 32)        896
#
#  batch_normalization_42 (Ba  (None, 32, 32, 32)        128
#  tchNormalization)
#
#  max_pooling2d_27 (MaxPooli  (None, 16, 16, 32)        0
#  ng2D)
#
#  conv2d_38 (Conv2D)          (None, 16, 16, 64)        18496
#
#  batch_normalization_43 (Ba  (None, 16, 16, 64)        256
#  tchNormalization)
#
#  max_pooling2d_28 (MaxPooli  (None, 8, 8, 64)          0
#  ng2D)
#
#  conv2d_39 (Conv2D)          (None, 8, 8, 128)         73856
#
#  batch_normalization_44 (Ba  (None, 8, 8, 128)         512
#  tchNormalization)
#
#  conv2d_40 (Conv2D)          (None, 8, 8, 128)         147584
#
#  batch_normalization_45 (Ba  (None, 8, 8, 128)         512
#  tchNormalization)
#
#  max_pooling2d_29 (MaxPooli  (None, 4, 4, 128)         0
#  ng2D)
#
#  flatten_9 (Flatten)         (None, 2048)              0
#
#  dense_27 (Dense)            (None, 256)               524544
#
#  dropout_18 (Dropout)        (None, 256)               0
#
#  dense_28 (Dense)            (None, 256)               65792
#
#  dropout_19 (Dropout)        (None, 256)               0
#
#  dense_29 (Dense)            (None, 10)                2570
#
# =================================================================
# Total params: 835158 (3.19 MB)
# Trainable params: 834448 (3.18 MB)
# Non-trainable params: 710 (2.77 KB)
# _________________________________________________________________

# %%
history1 = AlexNet.fit(x_train, y_train, epochs=100, validation_data=(x_test, y_test),verbose=1)
# Out:
# Epoch 1/100
# 1563/1563 [==============================] - 20s 11ms/step - loss: 2.1311 - accuracy: 0.4787 - val_loss: 1.6390 - val_accuracy: 0.5989
# Epoch 2/100
# 1563/1563 [==============================] - 13s 8ms/step - loss: 1.4661 - accuracy: 0.6482 - val_loss: 1.4921 - val_accuracy: 0.6548
# Epoch 3/100
# 1563/1563 [==============================] - 12s 8ms/step - loss: 1.3541 - accuracy: 0.7035 - val_loss: 1.3537 - val_accuracy: 0.7103
# Epoch 4/100
# 1563/1563 [==============================] - 13s 8ms/step - loss: 1.3080 - accuracy: 0.7341 - val_loss: 1.3244 - val_accuracy: 0.7198
# Epoch 5/100
# 1563/1563 [==============================] - 13s 8ms/step - loss: 1.2713 - accuracy: 0.7534 - val_loss: 1.3421 - val_accuracy: 0.7325
# Epoch 6/100
# 1563/1563 [==============================] - 13s 8ms/step - loss: 1.2348 - accuracy: 0.7676 - val_loss: 1.3129 - val_accuracy: 0.7351
# Epoch 7/100
# 1563/1563 [==============================] - 13s 9ms/step - loss: 1.2061 - accuracy: 0.7771 - val_loss: 1.2341 - val_accuracy: 0.7609
# Epoch 8/100
# 1563/1563 [==============================] - 13s 8ms/step - loss: 1.1834 - accuracy: 0.7840 - val_loss: 1.2341 - val_accuracy: 0.7731
# Epoch 9/100
# 1563/1563 [==============================] - 13s 8ms/step - loss: 1.1623 - accuracy: 0.7922 - val_loss: 1.2334 - val_accuracy: 0.7615
# Epoch 10/100
# 1563/1563 [==============================] - 12s 8ms/step - loss: 1.1419 - accuracy: 0.7985 - val_loss: 1.2076 - val_accuracy: 0.7701
# Epoch 11/100
# 1563/1563 [==============================] - 13s 8ms/step - loss: 1.1204 - accuracy: 0.8023 - val_loss: 1.1947 - val_accuracy: 0.7713
# Epoch 12/100
# 1563/1563 [==============================] - 13s 8ms/step - loss: 1.1053 - accuracy: 0.8049 - val_loss: 1.3803 - val_accuracy: 0.7258
# Epoch 13/100
# 1563/1563 [==============================] - 13s 8ms/step - loss: 1.0928 - accuracy: 0.8093 - val_loss: 1.1923 - val_accuracy: 0.7760
# Epoch 14/100
# 1563/1563 [==============================] - 12s 8ms/step - loss: 1.0825 - accuracy: 0.8121 - val_loss: 1.1917 - val_accuracy: 0.7730
# Epoch 15/100
# 1563/1563 [==============================] - 13s 8ms/step - loss: 1.0669 - accuracy: 0.8150 - val_loss: 1.2387 - val_accuracy: 0.7600
# Epoch 16/100
# 1563/1563 [==============================] - 13s 8ms/step - loss: 1.0579 - accuracy: 0.8173 - val_loss: 1.1670 - val_accuracy: 0.7768
# Epoch 17/100
# 1563/1563 [==============================] - 13s 8ms/step - loss: 1.0477 - accuracy: 0.8191 - val_loss: 1.1476 - val_accuracy: 0.7829
# Epoch 18/100
# 1563/1563 [==============================] - 13s 9ms/step - loss: 1.0402 - accuracy: 0.8223 - val_loss: 1.1587 - val_accuracy: 0.7818
# Epoch 19/100
# 1563/1563 [==============================] - 12s 8ms/step - loss: 1.0306 - accuracy: 0.8235 - val_loss: 1.1316 - val_accuracy: 0.7853
# Epoch 20/100
# 1563/1563 [==============================] - 12s 8ms/step - loss: 1.0186 - accuracy: 0.8266 - val_loss: 1.1887 - val_accuracy: 0.7728
# Epoch 21/100
# 1563/1563 [==============================] - 13s 8ms/step - loss: 1.0185 - accuracy: 0.8258 - val_loss: 1.1166 - val_accuracy: 0.7885
# Epoch 22/100
# 1563/1563 [==============================] - 14s 9ms/step - loss: 1.0114 - accuracy: 0.8301 - val_loss: 1.1163 - val_accuracy: 0.7948
# Epoch 23/100
# 1563/1563 [==============================] - 18s 11ms/step - loss: 1.0059 - accuracy: 0.8307 - val_loss: 1.2196 - val_accuracy: 0.7626
# Epoch 24/100
# 1563/1563 [==============================] - 14s 9ms/step - loss: 1.0009 - accuracy: 0.8296 - val_loss: 1.1613 - val_accuracy: 0.7772
# Epoch 25/100
# 1563/1563 [==============================] - 13s 8ms/step - loss: 1.0064 - accuracy: 0.8298 - val_loss: 1.1216 - val_accuracy: 0.7939
# Epoch 26/100
# 1563/1563 [==============================] - 14s 9ms/step - loss: 0.9961 - accuracy: 0.8313 - val_loss: 1.0794 - val_accuracy: 0.7981
# Epoch 27/100
# 1563/1563 [==============================] - 13s 8ms/step - loss: 0.9936 - accuracy: 0.8328 - val_loss: 1.1001 - val_accuracy: 0.7984
# Epoch 28/100
# 1563/1563 [==============================] - 12s 8ms/step - loss: 0.9851 - accuracy: 0.8345 - val_loss: 1.1189 - val_accuracy: 0.7906
# Epoch 29/100
# 1563/1563 [==============================] - 12s 8ms/step - loss: 0.9827 - accuracy: 0.8359 - val_loss: 1.2042 - val_accuracy: 0.7736
# Epoch 30/100
# 1563/1563 [==============================] - 13s 8ms/step - loss: 0.9838 - accuracy: 0.8340 - val_loss: 1.1613 - val_accuracy: 0.7787
# Epoch 31/100
# 1563/1563 [==============================] - 13s 8ms/step - loss: 0.9819 - accuracy: 0.8354 - val_loss: 1.1244 - val_accuracy: 0.7878
# Epoch 32/100
# 1563/1563 [==============================] - 13s 8ms/step - loss: 0.9830 - accuracy: 0.8375 - val_loss: 1.0918 - val_accuracy: 0.7965
# Epoch 33/100
# 1563/1563 [==============================] - 13s 8ms/step - loss: 0.9793 - accuracy: 0.8360 - val_loss: 1.0961 - val_accuracy: 0.7948
# Epoch 34/100
# 1563/1563 [==============================] - 12s 8ms/step - loss: 0.9714 - accuracy: 0.8375 - val_loss: 1.1031 - val_accuracy: 0.7871
# Epoch 35/100
# 1563/1563 [==============================] - 13s 9ms/step - loss: 0.9670 - accuracy: 0.8384 - val_loss: 1.1592 - val_accuracy: 0.7786
# Epoch 36/100
# 1563/1563 [==============================] - 12s 8ms/step - loss: 0.9648 - accuracy: 0.8398 - val_loss: 1.1419 - val_accuracy: 0.7847
# Epoch 37/100
# 1563/1563 [==============================] - 13s 8ms/step - loss: 0.9613 - accuracy: 0.8411 - val_loss: 1.1318 - val_accuracy: 0.7851
# Epoch 38/100
# 1563/1563 [==============================] - 13s 8ms/step - loss: 0.9660 - accuracy: 0.8404 - val_loss: 1.1588 - val_accuracy: 0.7800
# Epoch 39/100
# 1563/1563 [==============================] - 13s 8ms/step - loss: 0.9586 - accuracy: 0.8397 - val_loss: 1.1430 - val_accuracy: 0.7839
# Epoch 40/100
# 1563/1563 [==============================] - 13s 8ms/step - loss: 0.9543 - accuracy: 0.8408 - val_loss: 1.0736 - val_accuracy: 0.8001
# Epoch 41/100
# 1563/1563 [==============================] - 13s 8ms/step - loss: 0.9608 - accuracy: 0.8407 - val_loss: 1.1236 - val_accuracy: 0.7880
# Epoch 42/100
# 1563/1563 [==============================] - 12s 8ms/step - loss: 0.9499 - accuracy: 0.8398 - val_loss: 1.0909 - val_accuracy: 0.7936
# Epoch 43/100
# 1563/1563 [==============================] - 13s 8ms/step - loss: 0.9490 - accuracy: 0.8398 - val_loss: 1.1001 - val_accuracy: 0.7940
# Epoch 44/100
# 1563/1563 [==============================] - 14s 9ms/step - loss: 0.9463 - accuracy: 0.8409 - val_loss: 1.0825 - val_accuracy: 0.7937
# Epoch 45/100
# 1563/1563 [==============================] - 13s 8ms/step - loss: 0.9443 - accuracy: 0.8425 - val_loss: 1.1443 - val_accuracy: 0.7767
# Epoch 46/100
# 1563/1563 [==============================] - 13s 8ms/step - loss: 0.9377 - accuracy: 0.8428 - val_loss: 1.1169 - val_accuracy: 0.7876
# Epoch 47/100
# 1563/1563 [==============================] - 13s 8ms/step - loss: 0.9420 - accuracy: 0.8412 - val_loss: 1.1340 - val_accuracy: 0.7855
# Epoch 48/100
# 1563/1563 [==============================] - 13s 8ms/step - loss: 0.9347 - accuracy: 0.8451 - val_loss: 1.0606 - val_accuracy: 0.8043
# Epoch 49/100
# 1563/1563 [==============================] - 13s 8ms/step - loss: 0.9316 - accuracy: 0.8454 - val_loss: 1.0635 - val_accuracy: 0.7943
# Epoch 50/100
# 1563/1563 [==============================] - 14s 9ms/step - loss: 0.9293 - accuracy: 0.8454 - val_loss: 1.0566 - val_accuracy: 0.8029
# Epoch 51/100
# 1563/1563 [==============================] - 14s 9ms/step - loss: 0.9297 - accuracy: 0.8457 - val_loss: 1.1125 - val_accuracy: 0.7929
# Epoch 52/100
# 1563/1563 [==============================] - 14s 9ms/step - loss: 0.9282 - accuracy: 0.8464 - val_loss: 1.1077 - val_accuracy: 0.7874
# Epoch 53/100
# 1563/1563 [==============================] - 13s 9ms/step - loss: 0.9313 - accuracy: 0.8437 - val_loss: 1.0901 - val_accuracy: 0.7980
# Epoch 54/100
# 1563/1563 [==============================] - 13s 8ms/step - loss: 0.9268 - accuracy: 0.8453 - val_loss: 1.0665 - val_accuracy: 0.7973
# Epoch 55/100
# 1563/1563 [==============================] - 13s 8ms/step - loss: 0.9226 - accuracy: 0.8482 - val_loss: 1.1019 - val_accuracy: 0.7876
# Epoch 56/100
# 1563/1563 [==============================] - 13s 8ms/step - loss: 0.9212 - accuracy: 0.8484 - val_loss: 1.0835 - val_accuracy: 0.7968
# Epoch 57/100
# 1563/1563 [==============================] - 13s 8ms/step - loss: 0.9302 - accuracy: 0.8457 - val_loss: 1.1293 - val_accuracy: 0.7887
# Epoch 58/100
# 1563/1563 [==============================] - 13s 8ms/step - loss: 0.9192 - accuracy: 0.8486 - val_loss: 1.0631 - val_accuracy: 0.7975
# Epoch 59/100
# 1563/1563 [==============================] - 13s 8ms/step - loss: 0.9248 - accuracy: 0.8458 - val_loss: 1.0557 - val_accuracy: 0.8046
# Epoch 60/100
# 1563/1563 [==============================] - 13s 8ms/step - loss: 0.9229 - accuracy: 0.8477 - val_loss: 1.0701 - val_accuracy: 0.7976
# Epoch 61/100
# 1563/1563 [==============================] - 14s 9ms/step - loss: 0.9137 - accuracy: 0.8489 - val_loss: 1.0590 - val_accuracy: 0.8011
# Epoch 62/100
# 1563/1563 [==============================] - 13s 8ms/step - loss: 0.9180 - accuracy: 0.8480 - val_loss: 1.1131 - val_accuracy: 0.7885
# Epoch 63/100
# 1563/1563 [==============================] - 13s 9ms/step - loss: 0.9156 - accuracy: 0.8480 - val_loss: 1.0734 - val_accuracy: 0.7949
# Epoch 64/100
# 1563/1563 [==============================] - 13s 8ms/step - loss: 0.9163 - accuracy: 0.8494 - val_loss: 1.0965 - val_accuracy: 0.7904
# Epoch 65/100
# 1563/1563 [==============================] - 13s 8ms/step - loss: 0.9181 - accuracy: 0.8466 - val_loss: 1.0693 - val_accuracy: 0.7959
# Epoch 66/100
# 1563/1563 [==============================] - 13s 8ms/step - loss: 0.9120 - accuracy: 0.8498 - val_loss: 1.1190 - val_accuracy: 0.7859
# Epoch 67/100
# 1563/1563 [==============================] - 13s 8ms/step - loss: 0.9098 - accuracy: 0.8485 - val_loss: 1.1162 - val_accuracy: 0.7913
# Epoch 68/100
# 1563/1563 [==============================] - 13s 8ms/step - loss: 0.9240 - accuracy: 0.8459 - val_loss: 1.0692 - val_accuracy: 0.7999
# Epoch 69/100
# 1563/1563 [==============================] - 13s 9ms/step - loss: 0.9156 - accuracy: 0.8483 - val_loss: 1.2012 - val_accuracy: 0.7707
# Epoch 70/100
# 1563/1563 [==============================] - 13s 9ms/step - loss: 0.9123 - accuracy: 0.8503 - val_loss: 1.0641 - val_accuracy: 0.8020
# Epoch 71/100
# 1563/1563 [==============================] - 12s 8ms/step - loss: 0.9119 - accuracy: 0.8485 - val_loss: 1.1171 - val_accuracy: 0.7878
# Epoch 72/100
# 1563/1563 [==============================] - 13s 8ms/step - loss: 0.9119 - accuracy: 0.8516 - val_loss: 1.0797 - val_accuracy: 0.7973
# Epoch 73/100
# 1563/1563 [==============================] - 13s 8ms/step - loss: 0.9068 - accuracy: 0.8524 - val_loss: 1.1205 - val_accuracy: 0.7841
# Epoch 74/100
# 1563/1563 [==============================] - 12s 8ms/step - loss: 0.9105 - accuracy: 0.8497 - val_loss: 1.0982 - val_accuracy: 0.7907
# Epoch 75/100
# 1563/1563 [==============================] - 13s 8ms/step - loss: 0.9173 - accuracy: 0.8489 - val_loss: 1.0540 - val_accuracy: 0.8047
# Epoch 76/100
# 1563/1563 [==============================] - 12s 8ms/step - loss: 0.9073 - accuracy: 0.8513 - val_loss: 1.1005 - val_accuracy: 0.7871
# Epoch 77/100
# 1561/1563 [============================>.] - ETA: 0s - loss: 0.9046 - accuracy: 0.8526Epoch 78/100
# 1563/1563 [==============================] - 13s 8ms/step - loss: 0.9123 - accuracy: 0.8494 - val_loss: 1.0575 - val_accuracy: 0.8013
# Epoch 79/100
# 1563/1563 [==============================] - 12s 8ms/step - loss: 0.9115 - accuracy: 0.8500 - val_loss: 1.0721 - val_accuracy: 0.7936
# Epoch 80/100
# 1563/1563 [==============================] - 13s 8ms/step - loss: 0.9080 - accuracy: 0.8485 - val_loss: 1.0828 - val_accuracy: 0.7990
# Epoch 81/100
# 1563/1563 [==============================] - 12s 8ms/step - loss: 0.9070 - accuracy: 0.8513 - val_loss: 1.1115 - val_accuracy: 0.7886
# Epoch 82/100
# 1563/1563 [==============================] - 13s 8ms/step - loss: 0.9099 - accuracy: 0.8506 - val_loss: 1.0531 - val_accuracy: 0.8085
# Epoch 83/100
# 1563/1563 [==============================] - 12s 8ms/step - loss: 0.9071 - accuracy: 0.8511 - val_loss: 1.0852 - val_accuracy: 0.7904
# Epoch 84/100
# 1563/1563 [==============================] - 12s 8ms/step - loss: 0.9081 - accuracy: 0.8517 - val_loss: 1.0784 - val_accuracy: 0.7984
# Epoch 85/100
# 1563/1563 [==============================] - 12s 7ms/step - loss: 0.9067 - accuracy: 0.8500 - val_loss: 1.0920 - val_accuracy: 0.7912
# Epoch 86/100
# 1563/1563 [==============================] - 12s 8ms/step - loss: 0.9034 - accuracy: 0.8504 - val_loss: 1.0347 - val_accuracy: 0.8080
# Epoch 87/100
# 1563/1563 [==============================] - 13s 8ms/step - loss: 0.9096 - accuracy: 0.8493 - val_loss: 1.1205 - val_accuracy: 0.7836
# Epoch 88/100
# 1563/1563 [==============================] - 13s 8ms/step - loss: 0.9013 - accuracy: 0.8511 - val_loss: 1.0796 - val_accuracy: 0.7973
# Epoch 89/100
# 1563/1563 [==============================] - 13s 8ms/step - loss: 0.9019 - accuracy: 0.8517 - val_loss: 1.1109 - val_accuracy: 0.7899
# Epoch 90/100
# 1563/1563 [==============================] - 12s 8ms/step - loss: 0.9105 - accuracy: 0.8491 - val_loss: 1.0775 - val_accuracy: 0.7996
# Epoch 91/100
# 1563/1563 [==============================] - 12s 8ms/step - loss: 0.9061 - accuracy: 0.8505 - val_loss: 1.0683 - val_accuracy: 0.7987
# Epoch 92/100
# 1563/1563 [==============================] - 12s 8ms/step - loss: 0.9021 - accuracy: 0.8513 - val_loss: 1.0757 - val_accuracy: 0.7929
# Epoch 93/100
# 1563/1563 [==============================] - 12s 8ms/step - loss: 0.9083 - accuracy: 0.8499 - val_loss: 1.0918 - val_accuracy: 0.7921
# Epoch 94/100
# 1563/1563 [==============================] - 12s 8ms/step - loss: 0.9044 - accuracy: 0.8522 - val_loss: 1.0873 - val_accuracy: 0.7907
# Epoch 95/100
# 1563/1563 [==============================] - 12s 8ms/step - loss: 0.9032 - accuracy: 0.8518 - val_loss: 1.0901 - val_accuracy: 0.7921
# Epoch 96/100
# 1563/1563 [==============================] - 13s 8ms/step - loss: 0.9018 - accuracy: 0.8525 - val_loss: 1.1248 - val_accuracy: 0.7790
# Epoch 97/100
# 1563/1563 [==============================] - 13s 8ms/step - loss: 0.9066 - accuracy: 0.8524 - val_loss: 1.0924 - val_accuracy: 0.8006
# Epoch 98/100
# 1563/1563 [==============================] - 12s 8ms/step - loss: 0.9068 - accuracy: 0.8508 - val_loss: 1.0634 - val_accuracy: 0.8020
# Epoch 99/100
# 1563/1563 [==============================] - 12s 8ms/step - loss: 0.9063 - accuracy: 0.8503 - val_loss: 1.0684 - val_accuracy: 0.8001
# Epoch 100/100
# 1563/1563 [==============================] - 12s 8ms/step - loss: 0.9046 - accuracy: 0.8518 - val_loss: 1.1036 - val_accuracy: 0.7911

# %%
# summarize history for accuracy
plt.plot(history1.history['accuracy'])
plt.plot(history1.history['val_accuracy'])
plt.title("Accuracy by AlexNet on CIFAR-10 Data")
plt.ylabel('Accuracy')
plt.xlabel('Epochs')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()
# summarize history for loss
plt.plot(history1.history['loss'])
plt.plot(history1.history['val_loss'])
plt.title('Loss by AlexNet on CIFAR-10 Data')
plt.ylabel('Loss')
plt.xlabel('Epochs')
plt.legend(['Train', 'Validation'])
plt.show()

# %%
y_predictions1 = AlexNet.predict(x_test)
y_predictions1.reshape(-1,)
y_predictions1= np.argmax(y_predictions1, axis=1)

confusion_matrix(y_test, y_predictions1)
# Out:
# 313/313 [==============================] - 1s 2ms/step
# array([[802,  10,  53,  21,  20,   3,   1,  32,  53,   5],
#        [ 17, 876,   6,   3,   2,   3,   6,  11,  42,  34],
#        [ 43,   5, 631,  59,  65,  53,  64,  60,  12,   8],
#        [ 12,   2,  22, 676,  55,  73,  58,  76,  19,   7],
#        [ 14,   0,  18,  36, 827,  11,  17,  70,   6,   1],
#        [  6,   1,  19, 175,  34, 626,  25, 107,   4,   3],
#        [  4,   2,  17,  55,  26,  10, 856,  21,   7,   2],
#        [  9,   0,   6,  23,  30,  11,   5, 913,   2,   1],
#        [ 54,  11,   8,  13,   3,   2,   6,  11, 884,   8],
#        [ 31,  54,   3,  12,   4,   6,   4,  38,  28, 820]])

# %%
# confusion matrix and accuracy
plt.figure(figsize=(7, 6))
plt.title('Confusion matrix of AlexNet Model', fontsize=16)
plt.imshow(confusion_matrix(y_test, y_predictions1))
plt.xticks(np.arange(10), classes, rotation=45, fontsize=12)
plt.yticks(np.arange(10), classes, fontsize=12)
plt.colorbar()
plt.show()

# %%
print("Test accuracy by AlexNet:", accuracy_score(y_test, y_predictions1))
# Out:
# Test accuracy by AlexNet: 0.7911

# %%
L = 8
W = 8
fig, axes = plt.subplots(L, W, figsize = (20,20))
axes = axes.ravel() #

for i in np.arange(0, L * W):
    axes[i].imshow(x_test[i])
    axes[i].set_title("Predicted = {}\n Actual  = {}".format(classes[y_predictions1[i]], classes[y_test[i]]))
    axes[i].axis('off')

plt.subplots_adjust(wspace=1)

# %% [markdown]
# Additional visualizations

# %%
# Get misclassified indices
misclassified_idx = np.where(y_predictions1 != y_test)[0]

# Select a subset of misclassified images
subset_idx = np.random.choice(misclassified_idx, size=25, replace=False)

# Create a grid of subplots
fig, axes = plt.subplots(nrows=5, ncols=5, figsize=(15, 10))

# Plot misclassified images
for i, idx in enumerate(subset_idx):
    ax = axes.flat[i]
    ax.imshow(x_test[idx])
    ax.set_title(f"Predicted: {classes[y_predictions1[idx]]}\nActual: {classes[y_test[idx]]}")
    ax.axis('off')

plt.tight_layout()
plt.show()

# %%
from sklearn.metrics import confusion_matrix, accuracy_score

# Calculate class-wise accuracy
class_accuracy = []
for i in range(len(classes)):
    true_positives = confusion_matrix(y_test, y_predictions1)[i, i]
    total_instances = np.sum(confusion_matrix(y_test, y_predictions1)[:, i])
    class_accuracy.append(true_positives / total_instances)

# Plot class-wise accuracy
fig, ax = plt.subplots(figsize=(10, 6))
ax.bar(classes, class_accuracy)
ax.set_xlabel('Classes', fontsize=12)
ax.set_ylabel('Accuracy', fontsize=12)
ax.set_title('Class-wise Accuracy', fontsize=16)
plt.xticks(rotation=90)
plt.show()
